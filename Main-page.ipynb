# %%
# %%html
# <h1 style="text-align: center; font-size: 25px;"> Welcome to PFHub </h1>
# <p style="font-size: 1.5em;">You can <strong style="background-color: #317399; padding: 0 5px; color: #fff;">type your
# text</strong> directly in the editor or paste it from a Word Doc, PDF, Excel etc.</p>
# Out:
# <h1 style="text-align: center; font-size: 25px;"> Welcome to PFHub </h1>
# <p style="font-size: 1.5em;">You can <strong style="background-color: #317399; padding: 0 5px; color: #fff;">type your
# text</strong> directly in the editor or paste it from a Word Doc, PDF, Excel etc.</p>
