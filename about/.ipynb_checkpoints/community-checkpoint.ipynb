# %% [markdown]
# # Community members
#
# # Active members of the benchmarking effort
#
# ---

# %% [markdown]
# <div class="person-card">
#     <img src="/images/olleheinonen.jpg">
#     <div class ="inner-card">
#         <p>Olle Heinonen</p>
#         <p>Computational material science omnivore at Argonne.</p>
#         <p>Email: heinonen@anl.gov</p>
#         <p>Github: heinono1</p>
#         <p>ORCID: 0000-0002-3618-6092</p>
#     </div>
# </div>
#
# <div class="person-card">
#     <img src="/images/jameswarren.jpg">
#     <div class="inner-card">
#         <p>James Warren</p>
#         <p>Director of the MGI program at NIST. Involved in phase field modeling since 1992.</p>
#         <p>Email: james.warren@nist.gov</p>
# </div>

# %%
import pandas as pd
from IPython.display import HTML, display

df = pd.read_csv('/Users/nicholasaagesen/pfhub.github.io/about/people.csv')

first_person = df.iloc[0]

#display(HTML(f'<p>{first_person["name"]} <br> {first_person["email"]} <br> </p>'))

img=first_person["images"]

display(HTML(f'<div class="person-card">'
    f'<img src="/images/jameswarren.jpg">'
    f'<div class="inner-card">'
        f'<p>James Warren</p>'
        f'<p>Director of the MGI program at NIST. Involved in phase field modeling since 1992.</p>'
        f'<p>Email: james.warren@nist.gov</p>'
f'</div>'))
# Out:
# <div class="person-card"><img src="/images/jameswarren.jpg"><div class="inner-card"><p>James Warren</p><p>Director of the MGI program at NIST. Involved in phase field modeling since 1992.</p><p>Email: james.warren@nist.gov</p></div>

# %% [markdown]
# <div class="person-card">
#     <img src=img>
#     <div class="inner-card">
#         <p>James Warren</p>
#         <p>Director of the MGI program at NIST. Involved in phase field modeling since 1992.</p>
#         <p>Email: james.warren@nist.gov</p>
# </div>
